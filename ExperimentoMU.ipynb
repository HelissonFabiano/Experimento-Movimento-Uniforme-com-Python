# %%
import pandas as pd

# %%
dados = pd.read_excel(r'C:\Users\helis\OneDrive\Área de Trabalho\Física\SEM 02\Laboratório de Física 1 - Mecânica\03 - Experimento MU\Dados MU.xlsx')

# %%
dados
# Out:
#     Ti (s)
# 0     6.27
# 1     6.24
# 2     6.41
# 3     6.09
# 4     6.36
# 5     6.85
# 6     6.45
# 7     6.32
# 8     6.49
# 9     6.71
# 10    6.37
# 11    6.48
# 12    6.58
# 13    6.22
# 14    6.05
# 15    6.29
# 16    6.21
# 17    6.10
# 18    6.47
# 19    6.16
# 20    6.29
# 21    6.56
# 22    6.13
# 23    6.31
# 24    6.44
# 25    6.59
# 26    6.36
# 27    6.36
# 28    6.27
# 29    6.55

# %%
dados['Di'] = dados['Ti (s)'] - dados['Ti (s)'].mean()

# %%
dados['Di²'] = dados['Di'].pow(2)

# %%
somaT = dados['Ti (s)'].sum()

# %%
somaT
# Out:
# np.float64(190.98000000000005)

# %%
mediaT = dados['Ti (s)'].mean()

# %%
mediaT
# Out:
# np.float64(6.366000000000001)

# %%
somaDi2 = dados['Di²'].sum()

# %%
somaDi2
# Out:
# np.float64(1.01552)

# %%
desvpad = dados['Ti (s)'].std()

# %%
dados[dados['Di'] > 3*desvpad]
# Out:
# Empty DataFrame
# Columns: [Ti (s), Di, Di²]
# Index: []

# %%
ictzpad = desvpad/(30**(1/2))

# %%
ictzpad
# Out:
# 0.03416525088179644

# %% [markdown]
# Incerteza Padrão: 0,0342 s
# Média: 6,366 s
# T = (6,3660 +- 0,0342)s

# %%
mediaT
# Out:
# np.float64(6.366000000000001)

# %%
veloc = 0.4/6.3660

# %%
veloc
# Out:
# 0.06283380458686774

# %%
ictz_veloc = veloc*(ictzpad/mediaT)

# %%
ictz_veloc
# Out:
# np.float64(0.0003372184570480848)

# %% [markdown]
# Velocidade Média: (0,0628 +- 0,0003) m/s

# %%
desvpad
# Out:
# 0.18713078590783178
